# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
from mpld3.display import display_d3, load_d3
load_d3() # this loads the d3.js library
# Out:
# <script type="text/javascript" src="http://d3js.org/d3.v3.min.js"></script>

# %%
# Now make a matplotlib plot

fig, ax = plt.subplots()
x, y = np.random.normal(0, 1, (2, 300))
ax.plot(x[::2], y[::2], 'ro', markersize=10, alpha=0.3)
ax.plot(x[1::2], y[1::2], 'bo', markersize=20, alpha=0.1)

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_title('Matplotlib Plot Rendered in D3!')

display_d3(fig)  # display the output using d3 SVG
# Out:
# <style>
# .axis line, .axis path {
#     shape-rendering: crispEdges;
#     stroke: black;
#     fill: none;
# }
#
# .axis text {
#     font-family: sans-serif;
#     font-size: 11px;
# }
#
# </style>
#
# <div id='chart4392601040'></div>
#
# <script type="text/javascript">
# var figwidth = 6.0 * 80;
# var figheight = 4.0 * 80;
#
# var chart_4392601040 = d3.select('#chart4392601040')
#                    .append('svg:svg')
#                    .attr('width', figwidth)
#                    .attr('height', figheight)
#                    .attr('class', 'chart');
#
#
# var axes_4392602064 = chart_4392601040.append('g')
# 	.attr('transform', 'translate(' + (0.125 * figwidth) + ',' +
#                                           (0.125 * figheight) + ')')
# 	.attr('width', 0.775 * figwidth)
# 	.attr('height', 0.775 * figheight)
# 	.attr('class', 'main');
#
# // draw the x axis
# var x_4392602064 = d3.scale.linear()
#                    .domain([-3.0, 3.0])
# ...
