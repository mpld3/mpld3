# %%
# imports widget side
# see https://github.com/ipython/ipython/blob/2.x/examples/Interactive%20Widgets/Custom%20Widgets.ipynb

from __future__ import print_function # For py 2.7 compat

from IPython.html import widgets # Widget definitions
from IPython.display import display # Used to display widgets in the notebook
from IPython.utils.traitlets import Unicode # Used to declare attributes of our widget
from IPython.html.widgets import interact, interactive, fixed

# %%
# imports render side
# see http://mpld3.github.io/examples/drag_points.html

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

import mpld3
from mpld3 import plugins, utils

# %%
# imports solve side
# see http://stackoverflow.com/questions/8739227/how-to-solve-a-pair-of-nonlinear-equations-using-python

from scipy.optimize import fsolve

#def expchelon(a, b, x):
#    return a * (1 - np.exp(-b * x))

#def fun(p1, p2):
#    x1, y1 = p1
#    x2, y2 = p2
#    def equations(p):
#        a, b = p
#        return (y1 - expchelon(a, b, x1), y2 - expchelon(a, b, x2))
#    return equations

#equations = fun((1,1), (2,4))
#a, b =  fsolve(equations, (1, 1))

#print((a, b), expchelon(a, b, 1), expchelon(a, b, 2))

# %%
# widget sync'd python side
class GraphWidget(widgets.DOMWidget):
    _view_name = Unicode('GraphView', sync=True)
    description = 'coord'    
    value = Unicode(sync=True)

# %%
# %%javascript
# //widget javascript side
# require(["widgets/js/widget", "widgets/js/manager"], function(widget, manager){
#     // is based on the DatePickerView
#     var GraphView = widget.DOMWidgetView.extend({
#         render: function() {
#             //@ attr id : this is the id we reach to in the dragended function in the DragPlugin
#             this.$text = $('<input />')
#                 .attr('type', 'text')
#                 .attr('id', 'feedback_widget')
#                 .appendTo(this.$el);
#         },
#
#         update: function() {
#             this.$text.val(this.model.get('value'));
#             return GraphView.__super__.update.apply(this);
#         },
#
#         events: {"change": "handle_change"},
#
#         handle_change: function(event) {
#             this.model.set('value', this.$text.val());
#             this.touch();
#         },
#     });
#
#     manager.WidgetManager.register_widget_view('GraphView', GraphView);
# });

# %%
# visu plugin
# based on DragPlugin
class DragPlugin(plugins.PluginBase):
    JAVASCRIPT = r"""
mpld3.register_plugin("drag", DragPlugin);
DragPlugin.prototype = Object.create(mpld3.Plugin.prototype);
DragPlugin.prototype.constructor = DragPlugin;
DragPlugin.prototype.requiredProps = ["id"];
DragPlugin.prototype.defaultProps = {}
function DragPlugin(fig, props){
    mpld3.Plugin.call(this, fig, props);
    mpld3.insert_css("#" + fig.figid + " path.dragging",
                     {"fill-opacity": "1.0 !important",
                      "stroke-opacity": "1.0 !important"});
};$

DragPlugin.prototype.draw = function(){
    var obj = mpld3.get_element(this.props.id);

    var drag = d3.behavior.drag()
        .origin(function(d) { return {x:obj.ax.x(d[0]),
                                      y:obj.ax.y(d[1])}; })
        .on("dragstart", dragstarted)
        .on("drag", dragged)
        .on("dragend", dragended);

    obj.elements()
       .data(obj.offsets)
       .style("cursor", "default")
       .call(drag);

    function dragstarted(d) {
      d3.event.sourceEvent.stopPropagation();
      d3.select(this).classed("dragging", true);
    }

    function dragged(d, i) {
      d[0] = obj.ax.x.invert(d3.event.x);
      d[1] = obj.ax.y.invert(d3.event.y);
      d3.select(this)
        .attr("transform", "translate(" + [d3.event.x,d3.event.y] + ")");
    }

    function dragended(d,i) {
      d3.select(this).classed("dragging", false);
      //console.log(this);
      // feed back the new position to python, calling the feedback widget
      $('#feedback_widget').val("" + i + "," + d[0] + "," + d[1]).trigger("change");
    }
}"""

    def __init__(self, points):
        if isinstance(points, mpl.lines.Line2D):
            suffix = "pts"
        else:
            suffix = None

        self.dict_ = {"type": "drag",
                      "id": utils.get_id(points, suffix)}

# %%
# fit and draw
class Fit(object):
    def __init__(self, simulate, double_seeding=False):
        self.simulate = simulate
        
        if double_seeding:
            self.recalc_param = self.recalc_param_double_seeding
        else:
            self.recalc_param = self.recalc_param_simple_seeding
        
        # i will draw initial points at random
        # the number of points will increase until we match arity with the function to be fit(ted?)
        pseudo_fit = []
        while len(pseudo_fit) < 100:
            # just in case, I want to avoid inifite loops...
            try:
                simulate(0, pseudo_fit)
                print("we have %d parameters"%len(pseudo_fit))
                break
            except IndexError:
                pseudo_fit.append(1)
                
        self.p = np.random.standard_exponential((len(pseudo_fit), 2))
        # first guess !
        self.fit = np.array(pseudo_fit)
                
    def make_equations(self):
        def equations(params):
            return self.p[:,1] - self.simulate(self.p[:,0], params)
            #return [xy[1] - self.simulate(xy[0], params) for xy in self.p]
        self.equations = equations
    
    def solve_on_seed(self, seed):
        this_fit = fsolve(self.equations, seed, xtol=0.01) #, full_output=True)
        #print(this_fit)
        error = np.linalg.norm(self.p[:,1] - self.simulate(self.p[:,0], this_fit))
        return np.append(error, this_fit)
    
    def recalc_param_double_seeding(self):
        self.make_equations()
        
        # we explore two 'seedings' :
        # previous fit & fresh start, i had problems with chasing bad solutions...
        
        seeds = [self.fit, np.ones(self.fit.shape)]
        fits = np.array([self.solve_on_seed(seed) for seed in seeds])
        #print(fits) # usually not so far one from the other...
        self.fit = np.min(fits, axis=0)[1:]
        #print(self.fit)
    
    def recalc_param_simple_seeding(self):
        self.make_equations()
        self.fit = fsolve(self.equations, np.ones(self.fit.shape), xtol=0.01)
        
    def redraw(self, coord):
        if coord != "":
            i, x, y = coord.split(",")
            i = int(i)
            self.p[i][0] = float(x)
            self.p[i][1] = float(y)
            #print(i,x,y)
        self.recalc_param()
        x = np.linspace(0, 10, 50) # 50 x points from 0 to 10
        y = self.simulate(x, self.fit)
        #y = a * x + b
    
        #print(coord)
        fig, ax = plt.subplots()
        #ax.plot(self.p[:,0], self.simulate(self.p[:,0], self.fit),'ob', alpha=0.2, markersize=5, markeredgewidth=1)
        points = ax.plot(self.p[:,0], self.p[:,1],'or', alpha=0.5, markersize=10, markeredgewidth=1)
        
        ax.plot(x,y,'r-')
        ax.set_title("Click and Drag\n, we match on : %s"%np.array_str(self.fit, precision=2), fontsize=12)

        plugins.connect(fig, DragPlugin(points[0]))

        fig_h = mpld3.display()
        display(fig_h)

# %%
# click and drag not active here, we just show how we fit

def simulate(x, params):
    return params[0] * np.arctan(params[1] * x + params[2])

Fit(simulate).redraw("")
# Out:
# we have 3 parameters
# /usr/lib/python3.4/site-packages/scipy/optimize/minpack.py:237: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# <style>
#
# </style>
#
# <div id="fig_el77421400475983983767831657806"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# mpld3.register_plugin("drag", DragPlugin);
# DragPlugin.prototype = Object.create(mpld3.Plugin.prototype);
# DragPlugin.prototype.constructor = DragPlugin;
# DragPlugin.prototype.requiredProps = ["id"];
# DragPlugin.prototype.defaultProps = {}
# function DragPlugin(fig, props){
#     mpld3.Plugin.call(this, fig, props);
#     mpld3.insert_css("#" + fig.figid + " path.dragging",
#                      {"fill-opacity": "1.0 !important",
#                       "stroke-opacity": "1.0 !important"});
# };$
#
# DragPlugin.prototype.draw = function(){
#     var obj = mpld3.get_element(this.props.id);
#
#     var drag = d3.behavior.drag()
#         .origin(function(d) { return {x:obj.ax.x(d[0]),
#                                       y:obj.ax.y(d[1])}; })
#         .on("dragstart", dragstarted)
#         .on("drag", dragged)
#         .on("dragend", dragended);
#
#     obj.elements()
#        .data(obj.offsets)
#        .style("cursor", "default")
#        .call(drag);
#
#     function dragstarted(d) {
#       d3.event.sourceEvent.stopPropagation();
#       d3.select(this).classed("dragging", true);
#     }
#
#     function dragged(d, i) {
#       d[0] = obj.ax.x.invert(d3.event.x);
#       d[1] = obj.ax.y.invert(d3.event.y);
#       d3.select(this)
#         .attr("transform", "translate(" + [d3.event.x,d3.event.y] + ")");
#     }
#
#     function dragended(d,i) {
#       d3.select(this).classed("dragging", false);
#       //console.log(this);
#       // feed back the new position to python, calling the feedback widget
#       $('#feedback_widget').val("" + i + "," + d[0] + "," + d[1]).trigger("change");
#     }
# }
#        mpld3.draw_figure("fig_el77421400475983983767831657806", {"axes": [{"lines": [{"linewidth": 1.0, "coordinates": "data", "yindex": 1, "data": "data02", "zorder": 2, "alpha": 1, "dasharray": "none", "xindex": 0, "id": "el7742140047593532888", "color": "#FF0000"}], "images": [], "markers": [{"edgewidth": 1, "coordinates": "data", "yindex": 1, "data": "data01", "markerpath": [[[0.0, 5.0], [1.3260155, 5.0], [2.597899353924267, 4.473168457941209], [3.5355339059327378, 3.5355339059327378], [4.473168457941209, 2.597899353924267], [5.0, 1.3260155], [5.0, 0.0], [5.0, -1.3260155], [4.473168457941209, -2.597899353924267], [3.5355339059327378, -3.5355339059327378], [2.597899353924267, -4.473168457941209], [1.3260155, -5.0], [0.0, -5.0], [-1.3260155, -5.0], [-2.597899353924267, -4.473168457941209], [-3.5355339059327378, -3.5355339059327378], [-4.473168457941209, -2.597899353924267], [-5.0, -1.3260155], [-5.0, 0.0], [-5.0, 1.3260155], [-4.473168457941209, 2.597899353924267], [-3.5355339059327378, 3.5355339059327378], [-2.597899353924267, 4.473168457941209], [-1.3260155, 5.0], [0.0, 5.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 0.5, "zorder": 2, "xindex": 0, "edgecolor": "#000000", "facecolor": "#FF0000", "id": "el7742140047593532104pts"}], "sharey": [], "bbox": [0.125, 0.09999999999999998, 0.775, 0.8], "id": "el7742140047598522496", "axes": [{"tickvalues": null, "position": "bottom", "grid": {"gridOn": false}, "nticks": 6, "fontsize": 12.0, "scale": "linear", "tickformat": null}, {"tickvalues": null, "position": "left", "grid": {"gridOn": false}, "nticks": 9, "fontsize": 12.0, "scale": "linear", "tickformat": null}], "ylim": [0.5, 4.5], "xlim": [0.0, 10.0], "xdomain": [0.0, 10.0], "paths": [], "axesbg": "#FFFFFF", "xscale": "linear", "sharex": [], "ydomain": [0.5, 4.5], "collections": [], "texts": [{"rotation": -0.0, "coordinates": "axes", "h_anchor": "middle", "id": "el7742140047593924312", "position": [0.5, 1.0144675925925926], "color": "#000000", "v_baseline": "auto", "zorder": 3, "alpha": 1, "text": "Click and Drag\n, we match on : [ 3.25  0.45  0.19]", "fontsize": 12.0}], "zoomable": true, "axesbgalpha": null, "yscale": "linear"}], "height": 480.0, "data": {"data01": [[0.8775980186107701, 0.6234869133829242], [1.436818282950276, 3.0224270463845126], [0.19370848395307044, 1.178305850893184]], "data02": [[0.0, 0.6010121145204352], [0.20408163265306123, 0.8819788986670745], [0.40816326530612246, 1.150055922501216], [0.6122448979591837, 1.4027382127781478], [0.8163265306122449, 1.6385330567433694], [1.0204081632653061, 1.8568447192044415], [1.2244897959183674, 2.0577908152454225], [1.4285714285714286, 2.2420022054034288], [1.6326530612244898, 2.4104408799854165], [1.836734693877551, 2.5642524072313853], [2.0408163265306123, 2.7046564557981414], [2.2448979591836737, 2.832871543728165], [2.4489795918367347, 2.9500672089074738], [2.6530612244897958, 3.0573364893420885], [2.857142857142857, 3.155682552901494], [3.0612244897959187, 3.2460146599919297], [3.2653061224489797, 3.3291499374640163], [3.4693877551020407, 3.405818513414721], [3.673469387755102, 3.476670377041252], [3.8775510204081636, 3.5422829137995264], [4.081632653061225, 3.6031684713953966], [4.285714285714286, 3.65978158354838], [4.4897959183673475, 3.7125256550412042], [4.6938775510204085, 3.7617590230472198], [4.8979591836734695, 3.807800377629055], [5.1020408163265305, 3.850933563661142], [5.3061224489795915, 3.8914118074926902], [5.510204081632653, 3.92946142128387], [5.714285714285714, 3.96528504061709], [5.918367346938775, 3.999064449618048], [6.122448979591837, 4.030963044268642], [6.326530612244898, 4.061127980008673], [6.530612244897959, 4.089692044804576], [6.73469387755102, 4.11677529401832], [6.938775510204081, 4.142486478860859], [7.142857142857143, 4.166924296069741], [7.346938775510204, 4.1901784827477755], [7.551020408163265, 4.21233077703653], [7.755102040816327, 4.233455762449617], [7.959183673469388, 4.253621611220345], [8.1632653061 ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3git.js", function(){
#
# mpld3.register_plugin("drag", DragPlugin);
# DragPlugin.prototype = Object.create(mpld3.Plugin.prototype);
# DragPlugin.prototype.constructor = DragPlugin;
# DragPlugin.prototype.requiredProps = ["id"];
# DragPlugin.prototype.defaultProps = {}
# function DragPlugin(fig, props){
#     mpld3.Plugin.call(this, fig, props);
#     mpld3.insert_css("#" + fig.figid + " path.dragging",
#                      {"fill-opacity": "1.0 !important",
#                       "stroke-opacity": "1.0 !important"});
# };$
#
# DragPlugin.prototype.draw = function(){
#     var obj = mpld3.get_element(this.props.id);
#
#     var drag = d3.behavior.drag()
#         .origin(function(d) { return {x:obj.ax.x(d[0]),
#                                       y:obj.ax.y(d[1])}; })
#         .on("dragstart", dragstarted)
#         .on("drag", dragged)
#         .on("dragend", dragended);
#
#     obj.elements()
#        .data(obj.offsets)
#        .style("cursor", "default")
#        .call(drag);
#
#     function dragstarted(d) {
#       d3.event.

# %%
def simulate(x, params):
    return params[0] * np.arctan(params[1] * x + params[2])

my_fit = Fit(simulate)
def f(coord):
    return my_fit.redraw(coord)
    
interact(f, coord=GraphWidget()) # you can hide the hugly details somewhere in code with what's in next cell
# Out:
# <style>
#
# </style>
#
# <div id="fig_el77421400475900880964611097655"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# mpld3.register_plugin("drag", DragPlugin);
# DragPlugin.prototype = Object.create(mpld3.Plugin.prototype);
# DragPlugin.prototype.constructor = DragPlugin;
# DragPlugin.prototype.requiredProps = ["id"];
# DragPlugin.prototype.defaultProps = {}
# function DragPlugin(fig, props){
#     mpld3.Plugin.call(this, fig, props);
#     mpld3.insert_css("#" + fig.figid + " path.dragging",
#                      {"fill-opacity": "1.0 !important",
#                       "stroke-opacity": "1.0 !important"});
# };$
#
# DragPlugin.prototype.draw = function(){
#     var obj = mpld3.get_element(this.props.id);
#
#     var drag = d3.behavior.drag()
#         .origin(function(d) { return {x:obj.ax.x(d[0]),
#                                       y:obj.ax.y(d[1])}; })
#         .on("dragstart", dragstarted)
#         .on("drag", dragged)
#         .on("dragend", dragended);
#
#     obj.elements()
#        .data(obj.offsets)
#        .style("cursor", "default")
#        .call(drag);
#
#     function dragstarted(d) {
#       d3.event.sourceEvent.stopPropagation();
#       d3.select(this).classed("dragging", true);
#     }
#
#     function dragged(d, i) {
#       d[0] = obj.ax.x.invert(d3.event.x);
#       d[1] = obj.ax.y.invert(d3.event.y);
#       d3.select(this)
#         .attr("transform", "translate(" + [d3.event.x,d3.event.y] + ")");
#     }
#
#     function dragended(d,i) {
#       d3.select(this).classed("dragging", false);
#       //console.log(this);
#       // feed back the new position to python, calling the feedback widget
#       $('#feedback_widget').val("" + i + "," + d[0] + "," + d[1]).trigger("change");
#     }
# }
#        mpld3.draw_figure("fig_el77421400475900880964611097655", {"axes": [{"lines": [{"linewidth": 1.0, "coordinates": "data", "yindex": 1, "data": "data02", "zorder": 2, "alpha": 1, "dasharray": "none", "xindex": 0, "id": "el7742140047586949384", "color": "#FF0000"}], "images": [], "markers": [{"edgewidth": 1, "coordinates": "data", "yindex": 1, "data": "data01", "markerpath": [[[0.0, 5.0], [1.3260155, 5.0], [2.597899353924267, 4.473168457941209], [3.5355339059327378, 3.5355339059327378], [4.473168457941209, 2.597899353924267], [5.0, 1.3260155], [5.0, 0.0], [5.0, -1.3260155], [4.473168457941209, -2.597899353924267], [3.5355339059327378, -3.5355339059327378], [2.597899353924267, -4.473168457941209], [1.3260155, -5.0], [0.0, -5.0], [-1.3260155, -5.0], [-2.597899353924267, -4.473168457941209], [-3.5355339059327378, -3.5355339059327378], [-4.473168457941209, -2.597899353924267], [-5.0, -1.3260155], [-5.0, 0.0], [-5.0, 1.3260155], [-4.473168457941209, 2.597899353924267], [-3.5355339059327378, 3.5355339059327378], [-2.597899353924267, 4.473168457941209], [-1.3260155, 5.0], [0.0, 5.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 0.5, "zorder": 2, "xindex": 0, "edgecolor": "#000000", "facecolor": "#FF0000", "id": "el7742140047586948656pts"}], "sharey": [], "bbox": [0.125, 0.09999999999999998, 0.775, 0.8], "id": "el7742140047588399984", "axes": [{"tickvalues": null, "position": "bottom", "grid": {"gridOn": false}, "nticks": 6, "fontsize": 12.0, "scale": "linear", "tickformat": null}, {"tickvalues": null, "position": "left", "grid": {"gridOn": false}, "nticks": 8, "fontsize": 12.0, "scale": "linear", "tickformat": null}], "ylim": [-3.0, 4.0], "xlim": [0.0, 10.0], "xdomain": [0.0, 10.0], "paths": [], "axesbg": "#FFFFFF", "xscale": "linear", "sharex": [], "ydomain": [-3.0, 4.0], "collections": [], "texts": [{"rotation": -0.0, "coordinates": "axes", "h_anchor": "middle", "id": "el7742140047586807536", "position": [0.5, 1.0144675925925926], "color": "#000000", "v_baseline": "auto", "zorder": 3, "alpha": 1, "text": "Click and Drag\n, we match on : [ 1.98  6.59 -4.19]", "fontsize": 12.0}], "zoomable": true, "axesbgalpha": null, "yscale": "linear"}], "height": 480.0, "data": {"data01": [[0.8474914863039412, 1.8835224647474949], [0.6468285485715617, 0.143655573485289], [2.311453027621438, 2.938184363869781]], "data02": [[0.0, -2.652661615811477], [0.20408163265306123, -2.446963358782199], [0.40816326530612246, -1.9511742575875548], [0.6122448979591837, -0.3062106786149728], [0.8163265306122449, 1.7305728953971224], [1.0204081632653061, 2.3718982650817697], [1.2244897959183674, 2.6169305386810655], [1.4285714285714286, 2.7421982637247946], [1.6326530612244898, 2.8176877086151], [1.836734693877551, 2.8680168880303514], [2.0408163265306123, 2.903925285244428], [2.2448979591836737, 2.9308180065520935], [2.4489795918367347, 2.9517046804427123], [2.6530612244897958, 2.9683918053253193], [2.857142857142857, 2.9820284545300275], [3.0612244897959187, 2.9933800355771445], [3.2653061224489797, 3.002975915242547], [3.4693877551020407, 3.011193814394795], [3.673469387755102, 3.018310438244682], [3.8775510204081636, 3.0245331056389966], [4.081632653061225, 3.0300202018054962], [4.285714285714286, 3.0348948033058667], [4.4897959183673475, 3.0392539929436575], [4.6938775510204085, 3.0431753749022707], [4.8979591836734695, 3.046721724654371], [5.1020408163265305, 3.049944368037534], [5.3061224489795915, 3.0528856769147072], [5.510204081632653, 3.0555809395351026], [5.714285714285714, 3.058059780999721], [5.918367346938775, 3.060347255185274], [6.122448979591837, 3.062464693467672], [6.326530612244898, 3.0644303711637084], [6.530612244897959, 3.0662600357765513], [6.73469387755102, 3.06796732935458], [6.938775510204081, 3.0695641289208395], [7.142857142857143, 3.0710608229306504], [7.346938775510204, 3.0724665373539697], [7.551020408163265, 3.073789321774276], [7.755102040816327, 3.0750363035163213], [7.959183673469388, 3.0762138160314243], [ ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3git.js", function(){
#
# mpld3.register_plugin("drag", DragPlugin);
# DragPlugin.prototype = Object.create(mpld3.Plugin.prototype);
# DragPlugin.prototype.constructor = DragPlugin;
# DragPlugin.prototype.requiredProps = ["id"];
# DragPlugin.prototype.defaultProps = {}
# function DragPlugin(fig, props){
#     mpld3.Plugin.call(this, fig, props);
#     mpld3.insert_css("#" + fig.figid + " path.dragging",
#                      {"fill-opacity": "1.0 !important",
#                       "stroke-opacity": "1.0 !important"});
# };$
#
# DragPlugin.prototype.draw = function(){
#     var obj = mpld3.get_element(this.props.id);
#
#     var drag = d3.behavior.drag()
#         .origin(function(d) { return {x:obj.ax.x(d[0]),
#                                       y:obj.ax.y(d[1])}; })
#         .on("dragstart", dragstarted)
#         .on("drag", dragged)
#         .on("dragend", dragended);
#
#     obj.elements()
#        .data(obj.offsets)
#        .style("cursor", "default")
#        .call(drag);
#
#     function dragstarted(d) {

# %%
# %%javascript
# $('#feedback_widget').hide();
