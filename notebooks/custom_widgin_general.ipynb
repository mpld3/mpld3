# %%
# imports widget side
# see https://github.com/ipython/ipython/blob/2.x/examples/Interactive%20Widgets/Custom%20Widgets.ipynb

from __future__ import print_function # For py 2.7 compat

from IPython.html import widgets # Widget definitions
from IPython.display import display # Used to display widgets in the notebook
from IPython.utils.traitlets import Unicode # Used to declare attributes of our widget
from IPython.html.widgets import interact, interactive, fixed

# %%
# imports render side
# see http://mpld3.github.io/examples/drag_points.html

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

import mpld3
from mpld3 import plugins, utils

# %%
# imports solve side
# see http://stackoverflow.com/questions/8739227/how-to-solve-a-pair-of-nonlinear-equations-using-python

from scipy.optimize import fsolve

#def expchelon(a, b, x):
#    return a * (1 - np.exp(-b * x))

#def fun(p1, p2):
#    x1, y1 = p1
#    x2, y2 = p2
#    def equations(p):
#        a, b = p
#        return (y1 - expchelon(a, b, x1), y2 - expchelon(a, b, x2))
#    return equations

#equations = fun((1,1), (2,4))
#a, b =  fsolve(equations, (1, 1))

#print((a, b), expchelon(a, b, 1), expchelon(a, b, 2))

# %%
# widget sync'd python side
class GraphWidget(widgets.DOMWidget):
    _view_name = Unicode('GraphView', sync=True)
    description = 'coord'    
    value = Unicode(sync=True)

# %%
# %%javascript
# //widget javascript side
# require(["widgets/js/widget"], function(WidgetManager){
#
#     // is based on the DatePickerView
#     var GraphView = IPython.DOMWidgetView.extend({
#         render: function() {
#             //@ attr id : this is the id we reach to in the dragended function in the DragPlugin
#             this.$text = $('<input />')
#                 .attr('type', 'text')
#                 .attr('id', 'feedback_widget')
#                 .appendTo(this.$el);
#         },
#
#         update: function() {
#             this.$text.val(this.model.get('value'));
#             return GraphView.__super__.update.apply(this);
#         },
#
#         events: {"change": "handle_change"},
#
#         handle_change: function(event) {
#             this.model.set('value', this.$text.val());
#             this.touch();
#         },
#     });
#
#     WidgetManager.register_widget_view('GraphView', GraphView);
# });

# %%
# visu plugin
# based on DragPlugin
class DragPlugin(plugins.PluginBase):
    JAVASCRIPT = r"""
mpld3.register_plugin("drag", DragPlugin);
DragPlugin.prototype = Object.create(mpld3.Plugin.prototype);
DragPlugin.prototype.constructor = DragPlugin;
DragPlugin.prototype.requiredProps = ["id"];
DragPlugin.prototype.defaultProps = {}
function DragPlugin(fig, props){
    mpld3.Plugin.call(this, fig, props);
    mpld3.insert_css("#" + fig.figid + " path.dragging",
                     {"fill-opacity": "1.0 !important",
                      "stroke-opacity": "1.0 !important"});
};$

DragPlugin.prototype.draw = function(){
    var obj = mpld3.get_element(this.props.id);

    var drag = d3.behavior.drag()
        .origin(function(d) { return {x:obj.ax.x(d[0]),
                                      y:obj.ax.y(d[1])}; })
        .on("dragstart", dragstarted)
        .on("drag", dragged)
        .on("dragend", dragended);

    obj.elements()
       .data(obj.offsets)
       .style("cursor", "default")
       .call(drag);

    function dragstarted(d) {
      d3.event.sourceEvent.stopPropagation();
      d3.select(this).classed("dragging", true);
    }

    function dragged(d, i) {
      d[0] = obj.ax.x.invert(d3.event.x);
      d[1] = obj.ax.y.invert(d3.event.y);
      d3.select(this)
        .attr("transform", "translate(" + [d3.event.x,d3.event.y] + ")");
    }

    function dragended(d,i) {
      d3.select(this).classed("dragging", false);
      //console.log(this);
      // feed back the new position to python, calling the feedback widget
      $('#feedback_widget').val("" + i + "," + d[0] + "," + d[1]).trigger("change");
    }
}"""

    def __init__(self, points):
        if isinstance(points, mpl.lines.Line2D):
            suffix = "pts"
        else:
            suffix = None

        self.dict_ = {"type": "drag",
                      "id": utils.get_id(points, suffix)}

# %%
# fit and draw
class Fit(object):
    def __init__(self, simulate, double_seeding=False):
        self.simulate = simulate
        
        if double_seeding:
            self.recalc_param = self.recalc_param_double_seeding
        else:
            self.recalc_param = self.recalc_param_simple_seeding
        
        # i will draw initial points at random
        # the number of points will increase until we match arity with the function to be fit(ted?)
        pseudo_fit = []
        while len(pseudo_fit) < 100:
            # just in case, I want to avoid inifite loops...
            try:
                simulate(0, pseudo_fit)
                print("we have %d parameters"%len(pseudo_fit))
                break
            except IndexError:
                pseudo_fit.append(1)
                
        self.p = np.random.standard_exponential((len(pseudo_fit), 2))
        # first guess !
        self.fit = np.array(pseudo_fit)
                
    def make_equations(self):
        def equations(params):
            return self.p[:,1] - self.simulate(self.p[:,0], params)
            #return [xy[1] - self.simulate(xy[0], params) for xy in self.p]
        self.equations = equations
    
    def solve_on_seed(self, seed):
        this_fit = fsolve(self.equations, seed, xtol=0.01) #, full_output=True)
        #print(this_fit)
        error = np.linalg.norm(self.p[:,1] - self.simulate(self.p[:,0], this_fit))
        return np.append(error, this_fit)
    
    def recalc_param_double_seeding(self):
        self.make_equations()
        
        # we explore two 'seedings' :
        # previous fit & fresh start, i had problems with chasing bad solutions...
        
        seeds = [self.fit, np.ones(self.fit.shape)]
        fits = np.array([self.solve_on_seed(seed) for seed in seeds])
        #print(fits) # usually not so far one from the other...
        self.fit = np.min(fits, axis=0)[1:]
        #print(self.fit)
    
    def recalc_param_simple_seeding(self):
        self.make_equations()
        self.fit = fsolve(self.equations, np.ones(self.fit.shape), xtol=0.01)
        
    def redraw(self, coord):
        if coord != "":
            i, x, y = coord.split(",")
            i = int(i)
            self.p[i][0] = float(x)
            self.p[i][1] = float(y)
            #print(i,x,y)
        self.recalc_param()
        x = np.linspace(0, 10, 50) # 50 x points from 0 to 10
        y = self.simulate(x, self.fit)
        #y = a * x + b
    
        #print(coord)
        fig, ax = plt.subplots()
        #ax.plot(self.p[:,0], self.simulate(self.p[:,0], self.fit),'ob', alpha=0.2, markersize=5, markeredgewidth=1)
        points = ax.plot(self.p[:,0], self.p[:,1],'or', alpha=0.5, markersize=10, markeredgewidth=1)
        
        ax.plot(x,y,'r-')
        ax.set_title("Click and Drag\n, we match on : %s"%np.array_str(self.fit, precision=2), fontsize=12)

        plugins.connect(fig, DragPlugin(points[0]))

        fig_h = mpld3.display()
        display(fig_h)

# %%
# click and drag not active here, we just show how we fit

def simulate(x, params):
    return params[0] * np.arctan(params[1] * x + params[2])

Fit(simulate).redraw("")
# Out:
# we have 3 parameters
# <style>
#
# </style>
#
# <div id="fig_el3426427069723446065687802"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# mpld3.register_plugin("drag", DragPlugin);
# DragPlugin.prototype = Object.create(mpld3.Plugin.prototype);
# DragPlugin.prototype.constructor = DragPlugin;
# DragPlugin.prototype.requiredProps = ["id"];
# DragPlugin.prototype.defaultProps = {}
# function DragPlugin(fig, props){
#     mpld3.Plugin.call(this, fig, props);
#     mpld3.insert_css("#" + fig.figid + " path.dragging",
#                      {"fill-opacity": "1.0 !important",
#                       "stroke-opacity": "1.0 !important"});
# };$
#
# DragPlugin.prototype.draw = function(){
#     var obj = mpld3.get_element(this.props.id);
#
#     var drag = d3.behavior.drag()
#         .origin(function(d) { return {x:obj.ax.x(d[0]),
#                                       y:obj.ax.y(d[1])}; })
#         .on("dragstart", dragstarted)
#         .on("drag", dragged)
#         .on("dragend", dragended);
#
#     obj.elements()
#        .data(obj.offsets)
#        .style("cursor", "default")
#        .call(drag);
#
#     function dragstarted(d) {
#       d3.event.sourceEvent.stopPropagation();
#       d3.select(this).classed("dragging", true);
#     }
#
#     function dragged(d, i) {
#       d[0] = obj.ax.x.invert(d3.event.x);
#       d[1] = obj.ax.y.invert(d3.event.y);
#       d3.select(this)
#         .attr("transform", "translate(" + [d3.event.x,d3.event.y] + ")");
#     }
#
#     function dragended(d,i) {
#       d3.select(this).classed("dragging", false);
#       //console.log(this);
#       // feed back the new position to python, calling the feedback widget
#       $('#feedback_widget').val("" + i + "," + d[0] + "," + d[1]).trigger("change");
#     }
# }
#        mpld3.draw_figure("fig_el3426427069723446065687802", {"id": "el342642706972344", "height": 320.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}, {"id": "el342642706179856pts", "type": "drag"}], "data": {"data01": [[0.504534623068902, 1.341887790411414], [0.8257304185769265, 2.38055399804624], [1.3792125782896576, 0.8384614444441707]], "data02": [[0.0, -1.5204954729486144], [0.20408163265306123, -1.517134480019851], [0.40816326530612246, 1.5113786074697189], [0.6122448979591837, 1.5199220759616776], [0.8163265306122449, 1.521133692188649], [1.0204081632653061, 1.5216177188958202], [1.2244897959183674, 1.5218782020487314], [1.4285714285714286, 1.5220409519167017], [1.6326530612244898, 1.5221522840005077], [1.836734693877551, 1.5222332410069037], [2.0408163265306123, 1.5222947616967255], [2.2448979591836737, 1.5223430953618529], [2.4489795918367347, 1.5223820715475187], [2.6530612244897958, 1.5224141678554852], [2.857142857142857, 1.5224410581556356], [3.0612244897959187, 1.5224639140497318], [3.2653061224489797, 1.5224835801159986], [3.4693877551020407, 1.52250068056702], [3.673469387755102, 1.5225156867203593], [3.8775510204081636, 1.5225289611101323], [4.081632653061225, 1.522540787159823], [4.285714285714286, 1.5225513896449443], [4.4897959183673475, 1.5225609491166847], [4.6938775510204085, 1.5225696122683703], [4.8979591836734695, 1.5225774995165466], [5.1020408163265305, 1.522584710632405], [5.3061224489795915, 1.5225913289844757], [5.510204081632653, 1.5225974247763565], [5.714285714285714, 1.5226030575466558], [5.918367346938775, 1.5226082781201082], [6.122448979591837, 1.5226131301454697], [6.326530612244898, 1.5226176513188163], [6.530612244897959, 1.5226218743648465], [6.73469387755102, 1.5226258278302582], [6.938775510204081, 1.5226295367298879], [7.142857142857143, 1.522633023076536], [7.346938775510204, 1.522636306318191], [7.551020408163265, 1.522639403701006], [7.755102040816327, 1.5226423305723267], [7.959183673469388, 1.5226451006350137], [8.16326530612245, 1.5226477261619582], [8.36734693877551, 1.5226502181778707], [8.571428571428571, 1.522652586614025], [8.775510204081632, 1.5226548404405371], [8.979591836734695, 1.522656987779896], [9.183673469387756, 1.5226590360047743], [9.387755102040817, 1.5226609918225968], [9.591836734693878, 1.5226628613489206], [9.795918367346939, 1.5226646501713084], [10.0, 1.5226663634051059]]}, "axes": [{"id": "el342642706814680", "axesbgalpha": null, "lines": [{"coordinates": "data", "id": "el342642706181592", "dasharray": "none", "color": "#FF0000", "yindex": 1, "data": "data02", "zorder": 2, "linewidth": 1.0, "alpha": 1, "xindex": 0}], "collections": [], "yscale": "linear", "axes": [{"tickformat": null, "nticks": 6, "tickvalues": null, "position": "bottom", "grid": {"gridOn": false}, "fontsize": 10.0, "scale": "linear"}, {"tickformat": null, "nticks": 10, "tickvalues": null, "position": "left", "grid": {"gridOn": false}, "fontsize": 10.0, "scale": "linear"}], "ydomain": [-2.0, 2.5], "images": [], "sharey": [], "paths": [], "ylim": [-2.0, 2.5], "xscale": "linear", "texts": [{"id": "el342642707503368", "v_baseline": "auto", "zorder": 3, "rotation": -0.0, "h_anchor": "middle", "fontsize": 12.0, "coordinates": "axes", "color": "#000000", "position": [0.5, 1.0224014336917562], "alpha": 1, "text": "Click and Drag\n, we match on : [  9.69e-01   1.26e+03  -4.31e+02]"}], "bbox": [0.125, 0.125, 0.775, 0.775], "zoomable": true, "xlim": [0.0, 10.0], "axesbg": "#FFFFFF", "sharex": [], "xdomain": [0.0, 10.0], "markers": [{"coordinates": "data", "id": "el342642706179856pts", "markerpath": [[[0.0, 5.0], [1.3260155, 5.0], [2.597899353924267, 4.473168457941209], [3.5355339059327378, 3.5355339059327378], [4.473168457941209, 2.597899353924267], [5.0, 1.3260155], [5.0, 0.0], [5.0, -1.3260155], [4.473168457941209, -2.597899353924267], [3.5355339059327378, -3.5355339059327378], [2.597899353924267, -4.47 ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3git.js", function(){
#
# mpld3.register_plugin("drag", DragPlugin);
# DragPlugin.prototype = Object.create(mpld3.Plugin.prototype);
# DragPlugin.prototype.constructor = DragPlugin;
# DragPlugin.prototype.requiredProps = ["id"];
# DragPlugin.prototype.defaultProps = {}
# function DragPlugin(fig, props){
#     mpld3.Plugin.call(this, fig, props);
#     mpld3.insert_css("#" + fig.figid + " path.dragging",
#                      {"fill-opacity": "1.0 !important",
#                       "stroke-opacity": "1.0 !important"});
# };$
#
# DragPlugin.prototype.draw = function(){
#     var obj = mpld3.get_element(this.props.id);
#
#     var drag = d3.behavior.drag()
#         .origin(function(d) { return {x:obj.ax.x(d[0]),
#                                       y:obj.ax.y(d[1])}; })
#         .on("dragstart", dragstarted)
#         .on("drag", dragged)
#         .on("dragend", dragended);
#
#     obj.elements()
#        .data(obj.offsets)
#        .style("cursor", "default")
#        .call(drag);
#
#     function dragstarted(d) {
#       d3.event.sou

# %%
def simulate(x, params):
    return params[0] * np.arctan(params[1] * x + params[2])

my_fit = Fit(simulate)
def f(coord):
    return my_fit.redraw(coord)
    
interact(f, coord=GraphWidget()) # you can hide the hugly details somewhere in code with what's in next cell
# Out:
# <style>
#
# </style>
#
# <div id="fig_el3426427074344642350709414"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# mpld3.register_plugin("drag", DragPlugin);
# DragPlugin.prototype = Object.create(mpld3.Plugin.prototype);
# DragPlugin.prototype.constructor = DragPlugin;
# DragPlugin.prototype.requiredProps = ["id"];
# DragPlugin.prototype.defaultProps = {}
# function DragPlugin(fig, props){
#     mpld3.Plugin.call(this, fig, props);
#     mpld3.insert_css("#" + fig.figid + " path.dragging",
#                      {"fill-opacity": "1.0 !important",
#                       "stroke-opacity": "1.0 !important"});
# };$
#
# DragPlugin.prototype.draw = function(){
#     var obj = mpld3.get_element(this.props.id);
#
#     var drag = d3.behavior.drag()
#         .origin(function(d) { return {x:obj.ax.x(d[0]),
#                                       y:obj.ax.y(d[1])}; })
#         .on("dragstart", dragstarted)
#         .on("drag", dragged)
#         .on("dragend", dragended);
#
#     obj.elements()
#        .data(obj.offsets)
#        .style("cursor", "default")
#        .call(drag);
#
#     function dragstarted(d) {
#       d3.event.sourceEvent.stopPropagation();
#       d3.select(this).classed("dragging", true);
#     }
#
#     function dragged(d, i) {
#       d[0] = obj.ax.x.invert(d3.event.x);
#       d[1] = obj.ax.y.invert(d3.event.y);
#       d3.select(this)
#         .attr("transform", "translate(" + [d3.event.x,d3.event.y] + ")");
#     }
#
#     function dragended(d,i) {
#       d3.select(this).classed("dragging", false);
#       //console.log(this);
#       // feed back the new position to python, calling the feedback widget
#       $('#feedback_widget').val("" + i + "," + d[0] + "," + d[1]).trigger("change");
#     }
# }
#        mpld3.draw_figure("fig_el3426427074344642350709414", {"id": "el342642707434464", "height": 320.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}, {"id": "el342642705651080pts", "type": "drag"}], "data": {"data01": [[0.48094925909329084, 0.7551917760918276], [0.9127889085637998, 1.2979100177432823], [3.0055120929609416, 2.3077281114145807]], "data02": [[0.0, -0.040110414344727036], [0.20408163265306123, 0.3131660449902398], [0.40816326530612246, 0.6458468249796943], [0.6122448979591837, 0.9417684326701278], [0.8163265306122449, 1.1948203307026808], [1.0204081632653061, 1.4065029096156207], [1.2244897959183674, 1.5820490281338038], [1.4285714285714286, 1.7276262266836235], [1.6326530612244898, 1.848954414100798], [1.836734693877551, 1.9508380074427247], [2.0408163265306123, 2.0371329536085496], [2.2448979591836737, 2.110872989977539], [2.4489795918367347, 2.17442949361601], [2.6530612244897958, 2.2296575271359154], [2.857142857142857, 2.27801514923452], [3.0612244897959187, 2.3206562482893522], [3.2653061224489797, 2.3585012135071723], [3.4693877551020407, 2.3922902832246313], [3.673469387755102, 2.4226237702545648], [3.8775510204081636, 2.449992481998463], [4.081632653061225, 2.474800847357182], [4.285714285714286, 2.497384615190523], [4.4897959183673475, 2.5180244972713406], [4.6938775510204085, 2.536956764807057], [4.8979591836734695, 2.554381541655217], [5.1020408163265305, 2.5704693438361863], [5.3061224489795915, 2.585366274097172], [5.510204081632653, 2.599198177468519], [5.714285714285714, 2.612073988356923], [5.918367346938775, 2.624088444117034], [6.122448979591837, 2.6353242987803385], [6.326530612244898, 2.6458541397983675], [6.530612244897959, 2.6557418874797407], [6.73469387755102, 2.665044039254228], [6.938775510204081, 2.673810707525267], [7.142857142857143, 2.6820864896154104], [7.346938775510204, 2.689911200391268], [7.551020408163265, 2.697320492004376], [7.755102040816327, 2.7043463803787127], [7.959183673469388, 2.7110176942985977], [8.16326530612245, 2.7173604599656187], [8.36734693877551, 2.7233982315212915], [8.571428571428571, 2.7291523761375545], [8.775510204081632, 2.734642320756369], [8.979591836734695, 2.739885766332943], [9.183673469387756, 2.7448988744429825], [9.387755102040817, 2.7496964303052263], [9.591836734693878, 2.7542919856089774], [9.795918367346939, 2.7586979839933647], [10.0, 2.762925871577528]]}, "axes": [{"id": "el342642706887960", "axesbgalpha": null, "lines": [{"coordinates": "data", "id": "el342642705650352", "dasharray": "none", "color": "#FF0000", "yindex": 1, "data": "data02", "zorder": 2, "linewidth": 1.0, "alpha": 1, "xindex": 0}], "collections": [], "yscale": "linear", "axes": [{"tickformat": null, "nticks": 6, "tickvalues": null, "position": "bottom", "grid": {"gridOn": false}, "fontsize": 10.0, "scale": "linear"}, {"tickformat": null, "nticks": 8, "tickvalues": null, "position": "left", "grid": {"gridOn": false}, "fontsize": 10.0, "scale": "linear"}], "ydomain": [-0.5, 3.0], "images": [], "sharey": [], "paths": [], "ylim": [-0.5, 3.0], "xscale": "linear", "texts": [{"id": "el342642705783048", "v_baseline": "auto", "zorder": 3, "rotation": -0.0, "h_anchor": "middle", "fontsize": 12.0, "coordinates": "axes", "color": "#000000", "position": [0.5, 1.0224014336917562], "alpha": 1, "text": "Click and Drag\n, we match on : [ 1.89  0.92 -0.02]"}], "bbox": [0.125, 0.125, 0.775, 0.775], "zoomable": true, "xlim": [0.0, 10.0], "axesbg": "#FFFFFF", "sharex": [], "xdomain": [0.0, 10.0], "markers": [{"coordinates": "data", "id": "el342642705651080pts", "markerpath": [[[0.0, 5.0], [1.3260155, 5.0], [2.597899353924267, 4.473168457941209], [3.5355339059327378, 3.5355339059327378], [4.473168457941209, 2.597899353924267], [5.0, 1.3260155], [5.0, 0.0], [5.0, -1.3260155], [4.473168457941209, -2.597899353924267], [3.5355339059327378, -3.5355339059327378], [2.597899353924267, -4.473168457941209], [1.32 ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3git.js", function(){
#
# mpld3.register_plugin("drag", DragPlugin);
# DragPlugin.prototype = Object.create(mpld3.Plugin.prototype);
# DragPlugin.prototype.constructor = DragPlugin;
# DragPlugin.prototype.requiredProps = ["id"];
# DragPlugin.prototype.defaultProps = {}
# function DragPlugin(fig, props){
#     mpld3.Plugin.call(this, fig, props);
#     mpld3.insert_css("#" + fig.figid + " path.dragging",
#                      {"fill-opacity": "1.0 !important",
#                       "stroke-opacity": "1.0 !important"});
# };$
#
# DragPlugin.prototype.draw = function(){
#     var obj = mpld3.get_element(this.props.id);
#
#     var drag = d3.behavior.drag()
#         .origin(function(d) { return {x:obj.ax.x(d[0]),
#                                       y:obj.ax.y(d[1])}; })
#         .on("dragstart", dragstarted)
#         .on("drag", dragged)
#         .on("dragend", dragended);
#
#     obj.elements()
#        .data(obj.offsets)
#        .style("cursor", "default")
#        .call(drag);
#
#     function dragstarted(d) {
#       d3.event.sourceEvent.stopPropagat

# %%
# %%javascript
# $('#feedback_widget').hide();
