# %% [markdown]
# # D3 Viewer for Matplotlib

# %% [markdown]
# This notebook shows a few examples of d3 views of matplotlib plots.
#
# Note that not every feature of matplotlib is yet implemented.  Here are a few examples:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
from mpld3.display import display_d3

# %%
# Scatter points
fig, ax = plt.subplots()
np.random.seed(0)
x, y = np.random.normal(0, 1, (2, 300))
ax.plot(x[::2], y[::2], 'ro', markersize=10, alpha=0.3)
ax.plot(x[1::2], y[1::2], 'bo', markersize=20, alpha=0.1)

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_title('Matplotlib Plot Rendered in D3!', size=14)

display_d3(fig)  # display the output using d3 SVG
# Out:
#     <script type="text/javascript" src="http://d3js.org/d3.v3.min.js"></script>
#
#     <style>
#
#     .grid .tick {
#       stroke: lightgrey;
#       opacity: 0.7;
#     }
#
#     .grid path {
#       stroke-width: 0;
#     }
#
#
#     div#figure43932880801387440381
#     .axes1.axis line, .axes1.axis path {
#         shape-rendering: crispEdges;
#         stroke: black;
#         fill: none;
#     }
#
#     div#figure43932880801387440381
#     .axes1.axis text {
#         font-family: sans-serif;
#         font-size: 10.0px;
#         fill: black;
#         stroke: none;
#     }
#
#
#     div#figure43932880801387440381
#     path.line11 {
#         stroke: #FF0000;
#         stroke-width: 1.0;
#         fill: none;
#         stroke-opacity: 0.3;
#     }
#
#     div#figure43932880801387440381
#     circle.points11 {
#         stroke-width: 0.5;
#         stroke: #000000;
#         fill: #FF0000;
#         fill-opacity: 0.3;
#         stroke-opacity: 0.3;
#     }
#
#
#     div#figure43932880801387440381
#     path.line12 {
#         stroke: #0000FF;
#         stroke-width: 1.0;
#         fill: none;
#         stroke-opacity: 0.1;
#     }
#
#     div#figure43932880801387440381
#     circle.points12 {
#         stroke-width: 0.5;
#         stroke: #000000;
#         fill: #0000FF;
#         fill-opacity: 0.1;
#         stroke-opacity: 0.1;
#     }
#
#
#
#
#     </style>
#
#     <div id='figure43932880801387440381'></div>
#
#     <script type="text/javascript">
#     func43932880801387440381 = function(figure){
#
#     var figwidth = 6.0 * 80;
#     var figheight = 4.0 * 80;
#
#     var canvas = figure.append('svg:svg')
#                    .attr('width', figwidth)
#                    .attr('height', figheight)
#                    .attr('class', 'canvas')
#
#
#     // create the x and y axis
#     var x_1 = d3.scale.linear()
#                        .domain([-3.0, 3.0])
#                        .range([0, 0.775 * figwidth]);
#
#     var y_1 = d3.scale.linear()
#                        .domain([-4.0, 3.0])
#                        .range([0.775 * figheight, 0]);
#
#     // zoom object for the axes
#     var zoom1 = d3.behavior.zoom()
#                     .x(x_1)
#                     .y(y_1)
#                     .on("zoom", zoomed1);
#
#     // create the axes itself
#     var axes_1 = canvas.append('g')
#             .attr('transform', 'translate(' + (0.125 * figwidth) + ',' +
#                               ((1 - 0.125 - 0.775) * figheight) + ')')
#             .attr('width', 0.775 * figwidth)
#             .attr('height', 0.775 * figheight)
#             .attr('class', 'main')
#             .call(zoom1);
#
#     // create the axes background
#     axes_1.append("svg:rect")
#                       .attr("width", 0.775 * figwidth)
#                       .attr("height", 0.775 * figheight)
#                       .attr("class", "bg1")
#                       .attr("fill", "#FCFCFC");
#
#     // axis factory functions: used for grid lines & axes
#     var create_xAxis_1 = function(){
#        return d3.svg.axis()
#             .scale(x_1)
#             .orient('bottom');
#     }
#
#     var create_yAxis_1 = function(){
#        return d3.svg.axis()
#             .scale(y_1)
#             .orient('left');
#     }
#
#     // draw the x axis
#     var xAxis_1 = create_xAxis_1();
#
#     axes_1.append('g')
#             .attr('transform', 'translate(0,' + (0.775 * figheight) + ')')
#             .attr('class', 'axes1 x axis')
#             .call(xAxis_1);
#
#     // draw the y axis
#     var yAxis_1 = create_yAxis_1();
#
#     axes_1.append('g')
#             .attr('transform', 'translate(0,0)')
#             .attr('class', 'axes1 y axis')
#             .call(yAxis_1);
#
#     // create the clip boundary
#     var clip_1 = axes_1.append("svg:clipPath")
#                              .attr("id", "clip1")
#                              .append("svg:rect")
#                              .attr("x", 0)
#                              .attr("y", 0)
#                              .attr("width", 0.775 * figwidth)
#                              .attr("height", 0.775 * figheight);
#
#     var unclipped_axes_1 = axes_1;
#
#     axes_1 = axes_1.append('g')
#             .attr("clip-path", "url(#clip1)");
#
#     // draw grid lines (if needed)
#     axes_1.append("g")
#          .attr("class", "axes1 x grid")
#          .attr("transform", "translate(0," + (0.775 * figheight) + ")")
#          .call(create_xAxis_1()
#                        .tickSize(-(0.775 * figheight), 0, 0)
#                        .tickFormat(""));
#
#
#     axes_1.append("g")
#          .attr("class", "axes1 y grid")
#          .call(create_yAxis_1()
#                        .tickSize(-(0.775 * figwidth), 0, 0)
#                        .tickFormat(""));
#
#
#     var data_11 = [[1.764052345967664, -1.3065268517353166], [0.9787379841057392, -0.11816404512856976], [1.8675579901499675, 0.6663830820319143], [0.9500884175255894, -1.3342584714027534], [-0.10321885179355784, 0.6937731526901325], [0.144043571160878, -0.13370155966843916], [0.7610377251469934, -1.1268258087567435], [0.44386323274542566, -0.38487980918127546], [1.4940790731576061, -0.042171451290578935], [0.31306770165090136, -0.0616264020956474], [-2.5529898158340787, -0.7196043885517929], [0.8644361988595057, 0.2745163577239395], [2.2697546239876076, -1.1573552591908536], [0.04575851730144607, -0.1576670161638159], [1.5327792143584575, -0.7047002758562337], [0.1549474256969163, 0.7471883342046318], [-0.8877857476301128, 0.7732529774025997], [-0.3479121493261526, -2.659172237996741], [1.2302906807277207, -1.7558905834377194], [-0.3873268174079523, -0.6840108977372166], [-1.0485529650670926, 1.068509399316009], [-1.7062701906250126, -0.6878376110286823], [-0.5096521817516535, -0.4409226322925914], [-1.2527953600499262, -0.3646935443916854], [-1.6138978475579515, 0.5785214977288784], [-0.8954665611936756, -0.764143923906443], [-0.510805137568873, 1.3645318481024713], [-0.028182228338654868, -0.6522935999350191], [0.06651722238316789, -1.8430695501566485], [-0.6343220936809636, -0.47965581400794766], [-0.672460447775951, 0.698457149107336], [-0.813146282044454, 0.9318483741143037], [0.17742614225375283, -0.01568211160255477], [-1.6301983469660446, -0.19065349358139935], [-0.9072983643832422, -0.26773353689396645], [0.7290905621775369, 0.280441705316296], [1.1394006845433007, 0.8416312640736364], [0.402341641177549, 0.04949498165009074], [-0.8707971491818818, 0.6433144650629279], [-0.31155253212737266, -0.20690367616397173], [-1.1651498407833565, -1.6981058194322545], [0.46566243973045984, -2.2555642294021894], [1.4882521937955997, 0.0386305518401881], [1.1787795711596507, -0.9855107376841507], [-1.0707526215105425, 1.6481349322075596], [-0.40317694697317963, 0.5672902778526694], [0.2082749780768603, -0.35343174875719907], [0.3563663971744019, -0.2918373627478628], [0.010500020720820478, 0.8579239242923363], [0.12691209270361992, 1.4665787155741776], [1.8831506970562544, -0.5986539369229861], [-1.2704849984857336, 0.7666631816450861], [-1.17312340511416, -1.7685384506770307], [-0.41361898075974735, 0.8145198224878663], [1.9229420264803847, -0.18505367100934153], [1.8675589604265699, -1.4465346995633879], [-0.8612256850547025, -0.3091144447717088], [-0.2680033709513804, 1.7327211869191332], [0.947251967773748, 0.3708250012811021], [0.6140793703460803, 1.5199948607657727], [0.37642553115562943, 0.9295051114795281], [0.298238174206056, -2.0946030712061448], [-0.6945678597313655, -0.130106954193704], [-0.43515355172163744, 0.9430460873225178], [0.6722947570124355, -0.5693120534701851], [-0.7699160744453164, -0.4668455460527625], [-0.6743326606573761, 0.8689634868967954], [-0.635846078378881, -0.9711045704444846], [0.5765908166149409, 0.8215857120497958], [0.3960067126616453, 0.8005648034309968], [-1.4912575927056055, -0.39522898265435435], [0.16667349537252904, -0.08593076697161273], [2.383144774863942, 0.8758327615873309], [-0.9128222254441586, 0.4574156062209908], [-1.3159074105115212, -0.7826291558275251], [-0.06824160532463124, -1.0546284639850139], [-0.7447548220484399, 0.4631303293186071], [-0.0984525244254323, 0.33890412521594454], [1.126635922106507, -0.46886418796679563], [-1.1474686524111024

# %%
# Draw lines
fig, ax = plt.subplots()
x = np.linspace(0, 10, 1000)
for offset in np.linspace(0, 3, 7):
    ax.plot(x, 0.9 * np.sin(x - offset), lw=5, alpha=0.4)
ax.set_ylim(-1.2, 1.0)
ax.text(5, -1.1, "Here are some curves", size=18)
display_d3(fig)
# Out:
#     <script type="text/javascript" src="http://d3js.org/d3.v3.min.js"></script>
#
#     <style>
#
#     .grid .tick {
#       stroke: lightgrey;
#       opacity: 0.7;
#     }
#
#     .grid path {
#       stroke-width: 0;
#     }
#
#
#     div#figure43933347361387440381
#     .axes1.axis line, .axes1.axis path {
#         shape-rendering: crispEdges;
#         stroke: black;
#         fill: none;
#     }
#
#     div#figure43933347361387440381
#     .axes1.axis text {
#         font-family: sans-serif;
#         font-size: 10.0px;
#         fill: black;
#         stroke: none;
#     }
#
#
#     div#figure43933347361387440381
#     path.line11 {
#         stroke: #0000FF;
#         stroke-width: 5;
#         fill: none;
#         stroke-opacity: 0.4;
#     }
#
#     div#figure43933347361387440381
#     circle.points11 {
#         stroke-width: 0.5;
#         stroke: #0000FF;
#         fill: #0000FF;
#         fill-opacity: 0.4;
#         stroke-opacity: 0.4;
#     }
#
#
#     div#figure43933347361387440381
#     path.line12 {
#         stroke: #007F00;
#         stroke-width: 5;
#         fill: none;
#         stroke-opacity: 0.4;
#     }
#
#     div#figure43933347361387440381
#     circle.points12 {
#         stroke-width: 0.5;
#         stroke: #007F00;
#         fill: #007F00;
#         fill-opacity: 0.4;
#         stroke-opacity: 0.4;
#     }
#
#
#     div#figure43933347361387440381
#     path.line13 {
#         stroke: #FF0000;
#         stroke-width: 5;
#         fill: none;
#         stroke-opacity: 0.4;
#     }
#
#     div#figure43933347361387440381
#     circle.points13 {
#         stroke-width: 0.5;
#         stroke: #FF0000;
#         fill: #FF0000;
#         fill-opacity: 0.4;
#         stroke-opacity: 0.4;
#     }
#
#
#     div#figure43933347361387440381
#     path.line14 {
#         stroke: #00BFBF;
#         stroke-width: 5;
#         fill: none;
#         stroke-opacity: 0.4;
#     }
#
#     div#figure43933347361387440381
#     circle.points14 {
#         stroke-width: 0.5;
#         stroke: #00BFBF;
#         fill: #00BFBF;
#         fill-opacity: 0.4;
#         stroke-opacity: 0.4;
#     }
#
#
#     div#figure43933347361387440381
#     path.line15 {
#         stroke: #BF00BF;
#         stroke-width: 5;
#         fill: none;
#         stroke-opacity: 0.4;
#     }
#
#     div#figure43933347361387440381
#     circle.points15 {
#         stroke-width: 0.5;
#         stroke: #BF00BF;
#         fill: #BF00BF;
#         fill-opacity: 0.4;
#         stroke-opacity: 0.4;
#     }
#
#
#     div#figure43933347361387440381
#     path.line16 {
#         stroke: #BFBF00;
#         stroke-width: 5;
#         fill: none;
#         stroke-opacity: 0.4;
#     }
#
#     div#figure43933347361387440381
#     circle.points16 {
#         stroke-width: 0.5;
#         stroke: #BFBF00;
#         fill: #BFBF00;
#         fill-opacity: 0.4;
#         stroke-opacity: 0.4;
#     }
#
#
#     div#figure43933347361387440381
#     path.line17 {
#         stroke: #000000;
#         stroke-width: 5;
#         fill: none;
#         stroke-opacity: 0.4;
#     }
#
#     div#figure43933347361387440381
#     circle.points17 {
#         stroke-width: 0.5;
#         stroke: #000000;
#         fill: #000000;
#         fill-opacity: 0.4;
#         stroke-opacity: 0.4;
#     }
#
#
#
#
#
#     </style>
#
#     <div id='figure43933347361387440381'></div>
#
#     <script type="text/javascript">
#     func43933347361387440381 = function(figure){
#
#     var figwidth = 6.0 * 80;
#     var figheight = 4.0 * 80;
#
#     var canvas = figure.append('svg:svg')
#                    .attr('width', figwidth)
#                    .attr('height', figheight)
#                    .attr('class', 'canvas')
#
#
#     // create the x and y axis
#     var x_1 = d3.scale.linear()
#                        .domain([0.0, 10.0])
#                        .range([0, 0.775 * figwidth]);
#
#     var y_1 = d3.scale.linear()
#                        .domain([-1.2, 1.0])
#                        .range([0.775 * figheight, 0]);
#
#     // zoom object for the axes
#     var zoom1 = d3.behavior.zoom()
#                     .x(x_1)
#                     .y(y_1)
#                     .on("zoom", zoomed1);
#
#     // create the axes itself
#     var axes_1 = canvas.append('g')
#             .attr('transform', 'translate(' + (0.125 * figwidth) + ',' +
#                               ((1 - 0.125 - 0.775) * figheight) + ')')
#             .attr('width', 0.775 * figwidth)
#             .attr('height', 0.775 * figheight)
#             .attr('class', 'main')
#             .call(zoom1);
#
#     // create the axes background
#     axes_1.append("svg:rect")
#                       .attr("width", 0.775 * figwidth)
#                       .attr("height", 0.775 * figheight)
#                       .attr("class", "bg1")
#                       .attr("fill", "#FCFCFC");
#
#     // axis factory functions: used for grid lines & axes
#     var create_xAxis_1 = function(){
#        return d3.svg.axis()
#             .scale(x_1)
#             .orient('bottom');
#     }
#
#     var create_yAxis_1 = function(){
#        return d3.svg.axis()
#             .scale(y_1)
#             .orient('left');
#     }
#
#     // draw the x axis
#     var xAxis_1 = create_xAxis_1();
#
#     axes_1.append('g')
#             .attr('transform', 'translate(0,' + (0.775 * figheight) + ')')
#             .attr('class', 'axes1 x axis')
#             .call(xAxis_1);
#
#     // draw the y axis
#     var yAxis_1 = create_yAxis_1();
#
#     axes_1.append('g')
#             .attr('transform', 'translate(0,0)')
#             .attr('class', 'axes1 y axis')
#             .call(yAxis_1);
#
#     // create the clip boundary
#     var clip_1 = axes_1.append("svg:clipPath")
#                              .attr("id", "clip1")
#                              .append("svg:rect")
#                              .attr("x", 0)
#                              .attr("y", 0)
#                              .attr("width", 0.775 * figwidth)
#                              .attr("height", 0.775 * figheight);
#
#     var unclipped_axes_1 = axes_1;
#
#     axes_1 = axes_1.append('g')
#             .attr("clip-path", "url(#clip1)");
#
#     // draw grid lines (if needed)
#     axes_1.append("g")
#          .attr("class", "axes1 x grid")
#          .attr("transform", "translate(0," + (0.775 * figheight) + ")")
#          .call(create_xAxis_1()
#                        .tickSize(-(0.775 * figheight), 0, 0)
#                        .tickFormat(""));
#
#
#     axes_1.append("g")
#          .attr("class", "axes1 y grid")
#          .call(create_yAxis_1()
#                        .tickSize(-(0.775 * figwidth), 0, 0)
#                        .tickFormat(""));
#
#
#     var data_11 = [[0.0, 0.0], [0.01001001001001001, 0.009008858558861266], [0.02002002002002002, 0.01801681443492613], [0.03003003003003003, 0.027022965035846523], [0.04004004004004004, 0.03602640795016198], [0.050050050050050046, 0.045026241037720766], [0.06006006006006006, 0.054021562520073875], [0.07007007007007007, 0.06301147107083273], [0.08008008008008008, 0.07199506590598152], [0.09009009009009009, 0.08097144687413546], [0.10010010010010009, 0.08993971454673533], [0.11011011011011011, 0.09889897030816973], [0.12012012012012012, 0.10784831644581597], [0.13013013013013014, 0.11678685623999034], [0.14014014014014015, 0.12571369405379898], [0.15015015015015015, 0.1346279354228801], [0.16016016016016016, 0.14352868714502898], [0.17017017017017017, 0.15241505736969632], [0.18018018018018017, 0.1612861556873511], [0.19019019019019018, 0.17014109321869925], [0.20020020020020018, 0.17897898270374868], [0.21021021021021022, 0.18779893859071264], [0.22022022022022023, 0.196600077124741], [0.23023023023023023, 0.20538151643647257], [0.24024024024024024, 0.21414237663039748], [0.2502502502502503, 0.22288177987302255], [0.2602602602602603, 0.23159885048082954], [0.2702702702702703, 0.24029271500801822], [0.2802802802802803, 0.24896250233402528], [0.2902902902902903, 0.25760734375081007], [0.3003003003003003, 0.26622637304989855], [0.3103103103103103, 0.2748187266091771], [0.3203203203203203, 0.2833835434794269], [0.3303303303303303, 0.2919199654705907], [0.34034034034034033, 0.3004271372377627], [0.35035035035035034, 0.3089042063668941], [0.36036036036036034, 0.3173503234602041], [0.37037037037037035, 0.3257646422212894], [0.38038038038038036, 0

# %%
# multiple subplots
fig = plt.figure(figsize=(8, 6))
fig.subplots_adjust(hspace=0.3)

np.random.seed(0)

for i in range(1, 5):
    ax = fig.add_subplot(2, 2, i)
    color = np.random.random(3)
    ax.plot(np.random.random(30), lw=2, c=color)
    ax.set_title("RGB = ({0:.2f}, {1:.2f}, {2:.2f})".format(*color),
                 size=14)
display_d3(fig)
# Out:
#     <script type="text/javascript" src="http://d3js.org/d3.v3.min.js"></script>
#
#     <style>
#
#     .grid .tick {
#       stroke: lightgrey;
#       opacity: 0.7;
#     }
#
#     .grid path {
#       stroke-width: 0;
#     }
#
#
#     div#figure43945895201387440381
#     .axes1.axis line, .axes1.axis path {
#         shape-rendering: crispEdges;
#         stroke: black;
#         fill: none;
#     }
#
#     div#figure43945895201387440381
#     .axes1.axis text {
#         font-family: sans-serif;
#         font-size: 10.0px;
#         fill: black;
#         stroke: none;
#     }
#
#
#     div#figure43945895201387440381
#     path.line11 {
#         stroke: #8BB699;
#         stroke-width: 2;
#         fill: none;
#         stroke-opacity: 1;
#     }
#
#     div#figure43945895201387440381
#     circle.points11 {
#         stroke-width: 0.5;
#         stroke: #8BB699;
#         fill: #8BB699;
#         fill-opacity: 1;
#         stroke-opacity: 1;
#     }
#
#
#
#
#
#     div#figure43945895201387440381
#     .axes2.axis line, .axes2.axis path {
#         shape-rendering: crispEdges;
#         stroke: black;
#         fill: none;
#     }
#
#     div#figure43945895201387440381
#     .axes2.axis text {
#         font-family: sans-serif;
#         font-size: 10.0px;
#         fill: black;
#         stroke: none;
#     }
#
#
#     div#figure43945895201387440381
#     path.line21 {
#         stroke: #90049D;
#         stroke-width: 2;
#         fill: none;
#         stroke-opacity: 1;
#     }
#
#     div#figure43945895201387440381
#     circle.points21 {
#         stroke-width: 0.5;
#         stroke: #90049D;
#         fill: #90049D;
#         fill-opacity: 1;
#         stroke-opacity: 1;
#     }
#
#
#
#
#
#     div#figure43945895201387440381
#     .axes3.axis line, .axes3.axis path {
#         shape-rendering: crispEdges;
#         stroke: black;
#         fill: none;
#     }
#
#     div#figure43945895201387440381
#     .axes3.axis text {
#         font-family: sans-serif;
#         font-size: 10.0px;
#         fill: black;
#         stroke: none;
#     }
#
#
#     div#figure43945895201387440381
#     path.line31 {
#         stroke: #D118D5;
#         stroke-width: 2;
#         fill: none;
#         stroke-opacity: 1;
#     }
#
#     div#figure43945895201387440381
#     circle.points31 {
#         stroke-width: 0.5;
#         stroke: #D118D5;
#         fill: #D118D5;
#         fill-opacity: 1;
#         stroke-opacity: 1;
#     }
#
#
#
#
#
#     div#figure43945895201387440381
#     .axes4.axis line, .axes4.axis path {
#         shape-rendering: crispEdges;
#         stroke: black;
#         fill: none;
#     }
#
#     div#figure43945895201387440381
#     .axes4.axis text {
#         font-family: sans-serif;
#         font-size: 10.0px;
#         fill: black;
#         stroke: none;
#     }
#
#
#     div#figure43945895201387440381
#     path.line41 {
#         stroke: #01AC44;
#         stroke-width: 2;
#         fill: none;
#         stroke-opacity: 1;
#     }
#
#     div#figure43945895201387440381
#     circle.points41 {
#         stroke-width: 0.5;
#         stroke: #01AC44;
#         fill: #01AC44;
#         fill-opacity: 1;
#         stroke-opacity: 1;
#     }
#
#
#
#
#     </style>
#
#     <div id='figure43945895201387440381'></div>
#
#     <script type="text/javascript">
#     func43945895201387440381 = function(figure){
#
#     var figwidth = 8.0 * 80;
#     var figheight = 6.0 * 80;
#
#     var canvas = figure.append('svg:svg')
#                    .attr('width', figwidth)
#                    .attr('height', figheight)
#                    .attr('class', 'canvas')
#
#
#     // create the x and y axis
#     var x_1 = d3.scale.linear()
#                        .domain([0.0, 30.0])
#                        .range([0, 0.352272727273 * figwidth]);
#
#     var y_1 = d3.scale.linear()
#                        .domain([0.0, 1.0])
#                        .range([0.336956521739 * figheight, 0]);
#
#     // zoom object for the axes
#     var zoom1 = d3.behavior.zoom()
#                     .x(x_1)
#                     .y(y_1)
#                     .on("zoom", zoomed1);
#
#     // create the axes itself
#     var axes_1 = canvas.append('g')
#             .attr('transform', 'translate(' + (0.125 * figwidth) + ',' +
#                               ((1 - 0.563043478261 - 0.336956521739) * figheight) + ')')
#             .attr('width', 0.352272727273 * figwidth)
#             .attr('height', 0.336956521739 * figheight)
#             .attr('class', 'main')
#             .call(zoom1);
#
#     // create the axes background
#     axes_1.append("svg:rect")
#                       .attr("width", 0.352272727273 * figwidth)
#                       .attr("height", 0.336956521739 * figheight)
#                       .attr("class", "bg1")
#                       .attr("fill", "#FCFCFC");
#
#     // axis factory functions: used for grid lines & axes
#     var create_xAxis_1 = function(){
#        return d3.svg.axis()
#             .scale(x_1)
#             .orient('bottom');
#     }
#
#     var create_yAxis_1 = function(){
#        return d3.svg.axis()
#             .scale(y_1)
#             .orient('left');
#     }
#
#     // draw the x axis
#     var xAxis_1 = create_xAxis_1();
#
#     axes_1.append('g')
#             .attr('transform', 'translate(0,' + (0.336956521739 * figheight) + ')')
#             .attr('class', 'axes1 x axis')
#             .call(xAxis_1);
#
#     // draw the y axis
#     var yAxis_1 = create_yAxis_1();
#
#     axes_1.append('g')
#             .attr('transform', 'translate(0,0)')
#             .attr('class', 'axes1 y axis')
#             .call(yAxis_1);
#
#     // create the clip boundary
#     var clip_1 = axes_1.append("svg:clipPath")
#                              .attr("id", "clip1")
#                              .append("svg:rect")
#                              .attr("x", 0)
#                              .attr("y", 0)
#                              .attr("width", 0.352272727273 * figwidth)
#                              .attr("height", 0.336956521739 * figheight);
#
#     var unclipped_axes_1 = axes_1;
#
#     axes_1 = axes_1.append('g')
#             .attr("clip-path", "url(#clip1)");
#
#     // draw grid lines (if needed)
#     axes_1.append("g")
#          .attr("class", "axes1 x grid")
#          .attr("transform", "translate(0," + (0.336956521739 * figheight) + ")")
#          .call(create_xAxis_1()
#                        .tickSize(-(0.336956521739 * figheight), 0, 0)
#                        .tickFormat(""));
#
#
#     axes_1.append("g")
#          .attr("class", "axes1 y grid")
#          .call(create_yAxis_1()
#                        .tickSize(-(0.352272727273 * figwidth), 0, 0)
#                        .tickFormat(""));
#
#
#     var data_11 = [[0.0, 0.5448831829968969], [1.0, 0.4236547993389047], [2.0, 0.6458941130666561], [3.0, 0.4375872112626925], [4.0, 0.8917730007820798], [5.0, 0.9636627605010293], [6.0, 0.3834415188257777], [7.0, 0.7917250380826646], [8.0, 0.5288949197529045], [9.0, 0.5680445610939323], [10.0, 0.925596638292661], [11.0, 0.07103605819788694], [12.0, 0.08712929970154071], [13.0, 0.02021839744032572], [14.0, 0.832619845547938], [15.0, 0.7781567509498505], [16.0, 0.8700121482468192], [17.0, 0.978618342232764], [18.0, 0.7991585642167236], [19.0, 0.46147936225293185], [20.0, 0.7805291762864555], [21.0, 0.11827442586893322], [22.0, 0.6399210213275238], [23.0, 0.1433532874090464], [24.0, 0.9446689170495839], [25.0, 0.5218483217500717], [26.0, 0.4146619399905236], [27.0, 0.26455561210462697], [28.0, 0.7742336894342167], [29.0, 0.45615033221654855]]
#
#     var line_11 = d3.svg.line()
#          .x(function(d) {return x_1(d[0]);})
#          .y(function(d) {return y_1(d[1]);})
#          .interpolate("linear");
#
#     axes_1.append("svg:path")
#                    .attr("d", line_11(data_11))
#                    .attr('class', 'line11');
#
#
#
#
#     canvas.append("text")
#         .text("RGB = (0.55, 0.72, 0.60)")
#         .attr("class", "axes-text")
#         .attr("x", 192.727272727)
#         .attr("y", figheight - 437.555555556)
#         .attr("font-size", "14.0px")
#         .attr("fill", "#000000")
#         .attr("transform", "rotate(-0.0,192.727272727," + (figheight - 437.555555556) + ")")
#         .attr("style", "text-anchor: middle;")
#
#
#     function zoomed1() {
#         //console.log(d3.event.translate);
#         //cons
